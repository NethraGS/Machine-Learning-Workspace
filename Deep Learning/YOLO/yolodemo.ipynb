# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")  
results = model("animals.jpg", show=True)
for r in results:
    for box in r.boxes:
        print(
            "Class:", r.names[int(box.cls)],
            "Confidence:", float(box.conf),
            "x, y cordinates", box.xyxy   # x1,y1,x2,y2
        )
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\negovin\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 1.1MB/s 5.6s.5s<0.1s6s9s1ss
#
# image 1/1 c:\Users\negovin\Machine Learning Workspace\Machine-Learning-Workspace\Deep Learning\YOLO\animals.jpg: 384x640 4 dogs, 1 horse, 1 cow, 4 elephants, 2 zebras, 1 giraffe, 82.6ms
# Speed: 4.8ms preprocess, 82.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Class: elephant Confidence: 0.9136713147163391 x, y cordinates tensor([[384.2137, 276.4343, 538.7287, 382.2301]])
# Class: zebra Confidence: 0.872976541519165 x, y cordinates tensor([[124.7559, 259.1662, 277.3406, 380.2416]])
# Class: zebra Confidence: 0.8116257190704346 x, y cordinates tensor([[151.2993,  60.0062, 309.3756, 171.8422]])
# Class: elephant Confidence: 0.7653257250785828 x, y cordinates tensor([[  8.7722, 257.8963, 115.9430, 382.6987]])
# Class: elephant Confidence: 0.6595308780670166 x, y cordinates tensor([[535.2357, 268.7006, 683.7374, 382.4370]])
# Class: dog Confidence: 0.5972974300384521 x, y cordinates tensor([[555.8126, 175.4978, 679.0637, 268.5152]])
# Class: giraffe Confidence: 0.5016229748725891 x, y cordinates tensor([[  6.6498,  62.2651, 166.4774, 172.7706]])
# Class: elephant Confidence: 0.47895458340644836 x, y cordinates tensor([[372.4219, 181.1199, 556.4736, 270.2953]])
# Class: dog Confidence: 0.3956788182258606 x, y cordinates tensor([[233.9637, 277.8123, 393.7234, 380.2787]])
# Class: horse Confidence: 0.36321672797203064 x, y cordinates tensor([[286.9232,  62.6080, 453.5400, 174.7449]])
# Class: dog Confidence: 0.32090526819229126 x, y cordinates tensor([[535.4284, 267.9852, 683.7161, 382.2213]])
# Class: cow Confidence: 0.30872830748558044 x, y cordinates tensor([[285.0282,  62.5251, 452.9490, 174.8893]])
# Class: dog Confidence: 0.2900417149066925 x, y cordinates tensor([[454.9256,  62.0911, 579.4698, 178.3152]])

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")  
results = model("cat.jpg", show=True)
for r in results:
    for box in r.boxes:
        print(
            "Class:", r.names[int(box.cls)],
            "Confidence:", float(box.conf),
            "x, y cordinates", box.xyxy   # x1,y1,x2,y2
        )
# Out:
# image 1/1 c:\Users\negovin\Machine Learning Workspace\Machine-Learning-Workspace\Deep Learning\YOLO\cat.jpg: 320x640 1 cat, 184.9ms
# Speed: 4.4ms preprocess, 184.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# Class: cat Confidence: 0.9157670140266418 x, y cordinates tensor([[341.9736,  39.5234, 566.8811, 333.7579]])
